# %%
# %pip install plyer
# %pip install tqdm

import pandas as pd
import numpy as np
import sqlite3
from datetime import datetime
from plyer import notification 
import requests
from tqdm import tqdm
# Out:
# Requirement already satisfied: plyer in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\users\cnmendes\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://restcountries.com/v3.1/all"

# %%
resposta = requests.get(url)
resposta.status_code
# Out:
# 200

# %%
if resposta.status_code == 200:
    data_json = resposta.json()
else:
    print('erro ao acessar a API')

# %%
import pandas as pd
paises = pd.DataFrame(data_json)
paises
# Out:
#                                                   name         tld cca2 ccn3  \
# 0    {'common': 'Wallis and Futuna', 'official': 'T...       [.wf]   WF  876
# 1    {'common': 'Iceland', 'official': 'Iceland', '...       [.is]   IS  352
# 2    {'common': 'Luxembourg', 'official': 'Grand Du...       [.lu]   LU  442
# 3    {'common': 'Mali', 'official': 'Republic of Ma...       [.ml]   ML  466
# 4    {'common': 'Comoros', 'official': 'Union of th...       [.km]   KM  174
# ..                                                 ...         ...  ...  ...
# 245  {'common': 'Aruba', 'official': 'Aruba', 'nati...       [.aw]   AW  533
# 246  {'common': 'Ghana', 'official': 'Republic of G...       [.gh]   GH  288
# 247  {'common': 'Saint Martin', 'official': 'Saint ...  [.fr, .gp]   MF  663
# 248  {'common': 'India', 'official': 'Republic of I...       [.in]   IN  356
# 249  {'common': 'Uganda', 'official': 'Republic of ...       [.ug]   UG  800
#
#     cca3 independent               status  unMember  \
# 0    WLF       False  officially-assigned     False
# 1    ISL        True  officially-assigned      True
# 2    LUX        True  officially-assigned      True
# 3    MLI        True  officially-assigned      True
# 4    COM        True  officially-assigned      True
# ..   ...         ...                  ...       ...
# 245  ABW       False  officially-assigned     False
# 246  GHA        True  officially-assigned      True
# 247  MAF       False  officially-assigned     False
# 248  IND        True  officially-assigned      True
# 249  UGA        True  officially-assigned      True
#
#                                             currencies  \
# 0        {'XPF': {'name': 'CFP franc', 'symbol': '₣'}}
# 1    {'ISK': {'name': 'Icelandic króna', 'symbol': ...
# 2             {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 3    {'XOF': {'name': 'West African CFA franc', 'sy...
# 4    {'KMF': {'name': 'Comorian franc', 'symbol': '...
# ..                                                 ...
# 245  {'AWG': {'name': 'Aruban florin', 'symbol': 'ƒ'}}
# 246  {'GHS': {'name': 'Ghanaian cedi', 'symbol': '₵'}}
# 247           {'EUR': {'name': 'Euro', 'symbol': '€'}}
# 248   {'INR': {'name': 'Indian rupee', 'symbol': '₹'}}
# 249  {'UGX': {'name': 'Ugandan shilling', 'symbol':...
#
#                                     idd  ...       continents  \
# 0    {'root': '+6', 'suffixes': ['81']}  ...        [Oceania]
# 1    {'root': '+3', 'suffixes': ['54']}  ...         [Europe]
# 2    {'root': '+3', 'suffixes': ['52']}  ...         [Europe]
# 3    {'root': '+2', 'suffixes': ['23']}  ...         [Africa]
# 4    {'root': '+2', 'suffixes': ['69']}  ...         [Africa]
# ..                                  ...  ...              ...
# 245  {'root': '+2', 'suffixes': ['97']}  ...  [North America]
# 246  {'root': '+2', 'suffixes': ['33']}  ...         [Africa]
# 247  {'root': '+5', 'suffixes': ['90']}  ...  [North America]
# 248   {'root': '+9', 'suffixes': ['1']}  ...           [Asia]
# 249  {'root': '+2', 'suffixes': ['56']}  ...         [Africa]
#
#                                                  flags  \
# 0    {'png': 'https://flagcdn.com/w320/wf.png', 'sv...
# 1    {'png': 'https://flagcdn.com/w320/is.png', 'sv...
# 2    {'png': 'https://flagcdn.com/w320/lu.png', 'sv...
# 3    {'png': 'https://flagcdn.com/w320/ml.png', 'sv...
# 4    {'png': 'https://flagcdn.com/w320/km.png', 'sv...
# ..                                                 ...
# 245  {'png': 'https://flagcdn.com/w320/aw.png', 'sv...
# 246  {'png': 'https://flagcdn.com/w320/gh.png', 'sv...
# 247  {'png': 'https://flagcdn.com/w320/mf.png', 'sv...
# 248  {'png': 'https://flagcdn.com/w320/in.png', 'sv...
# 249  {'png': 'https://flagcdn.com/w320/ug.png', 'sv...
#
#                                             coatOfArms startOfWeek  \
# 0                                                   {}      monday
# 1    {'png': 'https://mainfacts.com/media/images/co...      monday
# 2    {'png': 'https://mainfacts.com/media/images/co...      monday
# 3    {'png': 'https://mainfacts.com/media/images/co...      monday
# 4    {'png': 'https://mainfacts.com/media/images/co...      monday
# ..                                                 ...         ...
# 245  {'png': 'https://mainfacts.com/media/images/co...      monday
# 246  {'png': 'https://mainfacts.com/media/images/co...      monday
# 247                                                 {}      monday
# 248  {'png': 'https://mainfacts.com/media/images/co...      monday
# 249  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                        capitalInfo  \
# 0    {'latlng': [-13.95, -171.93]}
# 1      {'latlng': [64.15, -21.95]}
# 2         {'latlng': [49.6, 6.12]}
# 3        {'latlng': [12.65, -8.0]}
# 4       {'latlng': [-11.7, 43.23]}
# ..                             ...
# 245    {'latlng': [12.52, -70.03]}
# 246      {'latlng': [5.55, -0.22]}
# 247    {'latlng': [18.07, -63.08]}
# 248       {'latlng': [28.6, 77.2]}
# 249      {'latlng': [0.32, 32.55]}
#
#                                        postalCode cioc            gini  fifa  \
# 0    {'format': '#####', 'regex': '^(986\d{2})$'}  NaN             NaN   NaN
# 1         {'format': '###', 'regex': '^(\d{3})$'}  ISL  {'2017': 26.1}   ISL
# 2        {'format': '####', 'regex': '^(\d{4})$'}  LUX  {'2018': 35.4}   LUX
# 3                                             NaN  MLI  {'2009': 33.0}   MLI
# 4                                             NaN  COM  {'2014': 45.3}   COM
# ..                                            ...  ...             ...   ...
# 245                                           NaN  ARU             NaN   ARU
# 246                                           NaN  GHA  {'2016': 43.5}   GHA
# 247                         {'format': '### ###'}  NaN             NaN   NaN
# 248    {'format': '######', 'regex': '^(\d{6})$'}  IND  {'2011': 35.7}   IND
# 249                                           NaN  UGA  {'2016': 42.8}   UGA
#
#                                  borders
# 0                                    NaN
# 1                                    NaN
# 2                        [BEL, FRA, DEU]
# 3    [DZA, BFA, GIN, CIV, MRT, NER, SEN]
# 4                                    NaN
# ..                                   ...
# 245                                  NaN
# 246                      [BFA, CIV, TGO]
# 247                                [SXM]
# 248       [BGD, BTN, MMR, CHN, NPL, PAK]
# 249            [COD, KEN, RWA, SSD, TZA]
#
# [250 rows x 35 columns]

# %%
paises.columns
# Out:
# Index(['name', 'tld', 'cca2', 'ccn3', 'cca3', 'independent', 'status',
#        'unMember', 'currencies', 'idd', 'capital', 'altSpellings', 'region',
#        'subregion', 'languages', 'translations', 'latlng', 'landlocked',
#        'area', 'demonyms', 'flag', 'maps', 'population', 'car', 'timezones',
#        'continents', 'flags', 'coatOfArms', 'startOfWeek', 'capitalInfo',
#        'postalCode', 'cioc', 'gini', 'fifa', 'borders'],
#       dtype='object')

# %%
subregion = [sub for sub in paises['subregion']] 
semana = [week for week in paises['startOfWeek']]
nome = [pais['common'] for pais in paises['name']]

dados_filtrados = {
    'Nome': nome,
    'Semana': semana,
    'Subregiao': subregion
}
dados_filtrados

paises_novo = pd.DataFrame(dados_filtrados)
paises_novo
# Out:
#                   Nome  Semana        Subregiao
# 0    Wallis and Futuna  monday        Polynesia
# 1              Iceland  monday  Northern Europe
# 2           Luxembourg  monday   Western Europe
# 3                 Mali  monday   Western Africa
# 4              Comoros  monday   Eastern Africa
# ..                 ...     ...              ...
# 245              Aruba  monday        Caribbean
# 246              Ghana  monday   Western Africa
# 247       Saint Martin  monday        Caribbean
# 248              India  monday    Southern Asia
# 249             Uganda  monday   Eastern Africa
#
# [250 rows x 3 columns]

# %%
area_countries = [area for area in paises['area']] 
area_countries

capital_countries = [cap for cap in paises['capital']] 
capital_countries

status = [st for st in paises['status']]
status



dados_filtrados_countries = {
    'Area': area_countries,
    'Capital': capital_countries,
    'Status': status

}

paises_novo_2 = pd.DataFrame(dados_filtrados_countries)
paises_novo_2
# Out:
#           Area       Capital               Status
# 0        142.0    [Mata-Utu]  officially-assigned
# 1     103000.0   [Reykjavik]  officially-assigned
# 2       2586.0  [Luxembourg]  officially-assigned
# 3    1240192.0      [Bamako]  officially-assigned
# 4       1862.0      [Moroni]  officially-assigned
# ..         ...           ...                  ...
# 245      180.0  [Oranjestad]  officially-assigned
# 246   238533.0       [Accra]  officially-assigned
# 247       53.0     [Marigot]  officially-assigned
# 248  3287590.0   [New Delhi]  officially-assigned
# 249   241550.0     [Kampala]  officially-assigned
#
# [250 rows x 3 columns]

# %%
colunas = ['name', 'currencies', 'region', 'latlng', 'borders', 'area']
novo_dataframe = paises[colunas].copy()

def trocar_moeda(currencies):
    if isinstance(currencies, dict):
        for moeda in currencies:
            name = currencies[moeda].get('name', '')
            symbol = currencies[moeda].get('symbol', '')
            return f"{name} ({symbol})"
    return None


novo_dataframe['currency'] = novo_dataframe['currencies'].apply(trocar_moeda)


nome = [pais['common'] for pais in novo_dataframe['name']]
novo_dataframe['name'] = nome


columns_to_select = ['name', 'currency', 'region', 'latlng', 'borders', 'area']
paises_novo2 = novo_dataframe[columns_to_select]


display(paises_novo2)
# Out:
#                   name                     currency    region  \
# 0    Wallis and Futuna                CFP franc (₣)   Oceania
# 1              Iceland         Icelandic króna (kr)    Europe
# 2           Luxembourg                     Euro (€)    Europe
# 3                 Mali  West African CFA franc (Fr)    Africa
# 4              Comoros          Comorian franc (Fr)    Africa
# ..                 ...                          ...       ...
# 245              Aruba            Aruban florin (ƒ)  Americas
# 246              Ghana            Ghanaian cedi (₵)    Africa
# 247       Saint Martin                     Euro (€)  Americas
# 248              India             Indian rupee (₹)      Asia
# 249             Uganda        Ugandan shilling (Sh)    Africa
#
#                     latlng                              borders       area
# 0          [-13.3, -176.2]                                  NaN      142.0
# 1            [65.0, -18.0]                                  NaN   103000.0
# 2      [49.75, 6.16666666]                      [BEL, FRA, DEU]     2586.0
# 3             [17.0, -4.0]  [DZA, BFA, GIN, CIV, MRT, NER, SEN]  1240192.0
# 4    [-12.16666666, 44.25]                                  NaN     1862.0
# ..                     ...                                  ...        ...
# 245   [12.5, -69.96666666]                                  NaN      180.0
# 246            [8.0, -2.0]                      [BFA, CIV, TGO]   238533.0
# 247     [18.0708, 63.0501]                                [SXM]       53.0
# 248           [20.0, 77.0]       [BGD, BTN, MMR, CHN, NPL, PAK]  3287590.0
# 249            [1.0, 32.0]            [COD, KEN, RWA, SSD, TZA]   241550.0
#
# [250 rows x 6 columns]

# %%
from plyer import notification 
import requests
#Criando uma definição para ler a URL da API, trazer a notificação se foi bem sucedido a leitura ou não e transformar em um DataFrame
def alerta_base(url): #URL vai ser o parâmetro que vamos ter que passar
        resposta_url = requests.get(url)  #Criei essa variável resposta_url pra armazenar o request.get da url parâmetro
        print(resposta_url.status_code) #Vai printar o valor na tela
        if resposta_url.status_code == 200: #Condição pra verificar se a resposta foi 200 (Conexão bem sucedida)
            resposta_json = resposta_url.json() #Criei essa variável resposta_json pra armazenar a leitura JSON da resposta_url
            print(resposta_json) #Printa na tela o JSON da API
            df_json = pd.DataFrame(resposta_json) #Criei essa variável df_json pra armazenar e transformar o resposta_json em um DataFrame
            print(df_json) #Printa na tela o df_json
            print(df_json.info())
            print(df_json.shape)
            title = "Conexão bem sucedida" #Atribui a title a mensagem para que seja usada posteriormente no notification
        else: 
            title = "Houve algum erro de conexão" #Se der errado, vai aparecer na notificação essa mensagem de erro
    
    #Usando o notification.notify pra exibir a mensagem na tela
        notification.notify(  
        title="Alerta",
        message=title,
        timeout=10
        )

# %%
import pandas as pd
import sqlite3

def ajustar_tipos_de_dados(df):
    def processar_valor(valor):
        if isinstance(valor, list):
            return ', '.join(str(v) for v in valor)
        elif isinstance(valor, dict):
            return str(valor)
        else:
            return valor
    
    def processar_coluna(coluna):
        return coluna.apply(processar_valor)
    
    return df.apply(processar_coluna)

# Função para salvar no banco de dados SQLite
def salva_bd(df, nome_tabela):
    '''
    Salva dataframe df na tabela nome_tabela.
    '''
    conn = sqlite3.connect('projetofinal.db')

    # Ajustar tipos de dados complexos
    df = ajustar_tipos_de_dados(df)

    df.to_sql(nome_tabela, conn, if_exists='replace', index=False)

    conn.close()

    return True


# Salvando os DataFrames no banco de dados
salva_bd(paises_novo, 'paises_informacoes_basicas')
salva_bd(paises_novo_2, 'paises_informacoes_adicionais')
salva_bd(paises_novo2, 'paises_moedas')

# Função para listar as tabelas no banco de dados SQLite
def tabelas_bd():
    conn = sqlite3.connect('projetofinal.db')
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    conn.close()
    return [table[0] for table in tables]

# Função para carregar dados de uma tabela do banco de dados SQLite
def carrega_bd(nome_tabela):
    conn = sqlite3.connect('projetofinal.db')
    query = f"SELECT * FROM {nome_tabela};"
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df


# Carregando uma tabela do banco de dados para verificar os dados salvos
df_carregado_1 = carrega_bd('paises_informacoes_basicas')
df_carregado_2 = carrega_bd('paises_informacoes_adicionais')
df_carregado_3 = carrega_bd('paises_moedas')

# Usando df.head() para imprimir as primeiras linhas de cada DataFrame
pd.DataFrame(df_carregado_1)
# Out:
#                   Nome  Semana        Subregiao
# 0    Wallis and Futuna  monday        Polynesia
# 1              Iceland  monday  Northern Europe
# 2           Luxembourg  monday   Western Europe
# 3                 Mali  monday   Western Africa
# 4              Comoros  monday   Eastern Africa
# ..                 ...     ...              ...
# 245              Aruba  monday        Caribbean
# 246              Ghana  monday   Western Africa
# 247       Saint Martin  monday        Caribbean
# 248              India  monday    Southern Asia
# 249             Uganda  monday   Eastern Africa
#
# [250 rows x 3 columns]

# %%
pd.DataFrame(df_carregado_2)
# Out:
#           Area     Capital               Status
# 0        142.0    Mata-Utu  officially-assigned
# 1     103000.0   Reykjavik  officially-assigned
# 2       2586.0  Luxembourg  officially-assigned
# 3    1240192.0      Bamako  officially-assigned
# 4       1862.0      Moroni  officially-assigned
# ..         ...         ...                  ...
# 245      180.0  Oranjestad  officially-assigned
# 246   238533.0       Accra  officially-assigned
# 247       53.0     Marigot  officially-assigned
# 248  3287590.0   New Delhi  officially-assigned
# 249   241550.0     Kampala  officially-assigned
#
# [250 rows x 3 columns]

# %%
pd.DataFrame(df_carregado_3)
# Out:
#                   name                     currency    region  \
# 0    Wallis and Futuna                CFP franc (₣)   Oceania
# 1              Iceland         Icelandic króna (kr)    Europe
# 2           Luxembourg                     Euro (€)    Europe
# 3                 Mali  West African CFA franc (Fr)    Africa
# 4              Comoros          Comorian franc (Fr)    Africa
# ..                 ...                          ...       ...
# 245              Aruba            Aruban florin (ƒ)  Americas
# 246              Ghana            Ghanaian cedi (₵)    Africa
# 247       Saint Martin                     Euro (€)  Americas
# 248              India             Indian rupee (₹)      Asia
# 249             Uganda        Ugandan shilling (Sh)    Africa
#
#                   latlng                            borders       area
# 0          -13.3, -176.2                               None      142.0
# 1            65.0, -18.0                               None   103000.0
# 2      49.75, 6.16666666                      BEL, FRA, DEU     2586.0
# 3             17.0, -4.0  DZA, BFA, GIN, CIV, MRT, NER, SEN  1240192.0
# 4    -12.16666666, 44.25                               None     1862.0
# ..                   ...                                ...        ...
# 245   12.5, -69.96666666                               None      180.0
# 246            8.0, -2.0                      BFA, CIV, TGO   238533.0
# 247     18.0708, 63.0501                                SXM       53.0
# 248           20.0, 77.0       BGD, BTN, MMR, CHN, NPL, PAK  3287590.0
# 249            1.0, 32.0            COD, KEN, RWA, SSD, TZA   241550.0
#
# [250 rows x 6 columns]

# %%
# %pip install virtualenv
# Out:
# Requirement already satisfied: virtualenv in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (20.26.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (from virtualenv) (0.3.8)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (from virtualenv) (3.15.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\cnmendes\appdata\roaming\python\python312\site-packages (from virtualenv) (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install virtualenvwrapper-win
# Out:
# Requirement already satisfied: virtualenvwrapper-win in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (1.2.7)
# Requirement already satisfied: virtualenv in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (from virtualenvwrapper-win) (20.26.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (from virtualenv->virtualenvwrapper-win) (0.3.8)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\cnmendes\appdata\local\programs\python\python312\lib\site-packages (from virtualenv->virtualenvwrapper-win) (3.15.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\cnmendes\appdata\roaming\python\python312\site-packages (from virtualenv->virtualenvwrapper-win) (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install jupyter
# Out:
# Requirement already satisfied: jupyter in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (1.0.0)
# Requirement already satisfied: notebook in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (7.2.1)
# Requirement already satisfied: qtconsole in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (6.29.4)
# Requirement already satisfied: ipywidgets in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter) (8.1.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: pygments in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from notebook->jupyter) (4.2.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: colorama in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (70.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: requests>=2.31 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip freeze
# Out:
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.2.0
# Babel==2.15.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# certifi==2024.6.2
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.2
# debugpy==1.8.1
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.8
# executing==2.0.1
# fastjsonschema==2.20.0
# filelock==3.15.3
# fqdn==1.5.1
# h11==0.14.0
# httpcore==1.0.5
# httpx==0.27.0
# idna==3.7
# ipykernel==6.29.4
# ipython==8.25.0
# ipywidgets==8.1.3
# isoduration==20.11.0
# jedi==0.19.1
# Jinja2==3.1.4
# json5==0.9.25
# jsonpointer==3.0.0
# jsonschema==4.22.0
# jsonschema-specifications==2023.12.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.10.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# jupyter_server==2.14.1
# jupyter_server_terminals==0.5.3
# jupyterlab==4.2.2
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.2
# jupyterlab_widgets==3.0.11
# MarkupSafe==2.1.5
# matplotlib-inline==0.1.7
# mistune==3.0.2
# nbclient==0.10.0
# nbconvert==7.16.4
# nbformat==5.10.4
# nest-asyncio==1.6.0
# notebook==7.2.1
# notebook_shim==0.2.4
# overrides==7.7.0
# packaging==24.1
# pandocfilters==1.5.1
# parso==0.8.4
# platformdirs==4.2.2
# prometheus_client==0.20.0
# prompt_toolkit==3.0.47
# psutil==6.0.0
# pure-eval==0.2.2
# pycparser==2.22
# Pygments==2.18.0
# python-dateutil==2.9.0.post0
# python-json-logger==2.0.7
# pywin32==306
# pywinpty==2.0.13
# PyYAML==6.0.1
# pyzmq==26.0.3
# qtconsole==5.5.2
# QtPy==2.4.1
# referencing==0.35.1
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.18.1
# Send2Trash==1.8.3
# setuptools==70.1.0
# six==1.16.0
# sniffio==1.3.1
# soupsieve==2.5
# stack-data==0.6.3
# terminado==0.18.1
# tinycss2==1.3.0
# tornado==6.4.1
# traitlets==5.14.3
# types-python-dateutil==2.9.0.20240316
# uri-template==1.3.0
# urllib3==2.2.2
# virtualenv==20.26.2
# virtualenvwrapper-win==1.2.7
# wcwidth==0.2.13
# webcolors==24.6.0
# webencodings==0.5.1
# websocket-client==1.8.0
# widgetsnbextension==4.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.4.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: asttokens==2.4.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: async-lru==2.0.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: attrs==23.2.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: Babel==2.15.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 8)) (2.15.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 9)) (4.12.3)
# Requirement already satisfied: bleach==6.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: certifi==2024.6.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 11)) (2024.6.2)
# Requirement already satisfied: cffi==1.16.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: colorama==0.4.6 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 15)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 17)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 18)) (0.7.1)
# Requirement already satisfied: distlib==0.3.8 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 19)) (0.3.8)
# Requirement already satisfied: executing==2.0.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 20)) (2.0.1)
# Requirement already satisfied: fastjsonschema==2.20.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 21)) (2.20.0)
# Requirement already satisfied: filelock==3.15.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 22)) (3.15.3)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: h11==0.14.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 24)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 25)) (1.0.5)
# Requirement already satisfied: httpx==0.27.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 26)) (0.27.0)
# Requirement already satisfied: idna==3.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 27)) (3.7)
# Requirement already satisfied: ipykernel==6.29.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 28)) (6.29.4)
# Requirement already satisfied: ipython==8.25.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 29)) (8.25.0)
# Requirement already satisfied: ipywidgets==8.1.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 30)) (8.1.3)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 31)) (20.11.0)
# Requirement already satisfied: jedi==0.19.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 32)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 33)) (3.1.4)
# Requirement already satisfied: json5==0.9.25 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 34)) (0.9.25)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 35)) (3.0.0)
# Requirement already satisfied: jsonschema==4.22.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 36)) (4.22.0)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 37)) (2023.12.1)
# Requirement already satisfied: jupyter==1.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 38)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 39)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.10.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 40)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 41)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 42)) (8.6.2)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 43)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.14.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 44)) (2.14.1)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 45)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.2.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 46)) (4.2.2)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 47)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 48)) (2.27.2)
# Requirement already satisfied: jupyterlab_widgets==3.0.11 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 49)) (3.0.11)
# Requirement already satisfied: MarkupSafe==2.1.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 50)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 51)) (0.1.7)
# Requirement already satisfied: mistune==3.0.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 52)) (3.0.2)
# Requirement already satisfied: nbclient==0.10.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 53)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 54)) (7.16.4)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 55)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 56)) (1.6.0)
# Requirement already satisfied: notebook==7.2.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 57)) (7.2.1)
# Requirement already satisfied: notebook_shim==0.2.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 58)) (0.2.4)
# Requirement already satisfied: overrides==7.7.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 59)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 60)) (24.1)
# Requirement already satisfied: pandocfilters==1.5.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 61)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 62)) (0.8.4)
# Requirement already satisfied: platformdirs==4.2.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 63)) (4.2.2)
# Requirement already satisfied: prometheus_client==0.20.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 64)) (0.20.0)
# Requirement already satisfied: prompt_toolkit==3.0.47 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 65)) (3.0.47)
# Requirement already satisfied: psutil==6.0.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 66)) (6.0.0)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 67)) (0.2.2)
# Requirement already satisfied: pycparser==2.22 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 68)) (2.22)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 69)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 70)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 71)) (2.0.7)
# Requirement already satisfied: pywin32==306 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 72)) (306)
# Requirement already satisfied: pywinpty==2.0.13 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 73)) (2.0.13)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 74)) (6.0.1)
# Requirement already satisfied: pyzmq==26.0.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 75)) (26.0.3)
# Requirement already satisfied: qtconsole==5.5.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 76)) (5.5.2)
# Requirement already satisfied: QtPy==2.4.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 77)) (2.4.1)
# Requirement already satisfied: referencing==0.35.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 78)) (0.35.1)
# Requirement already satisfied: requests==2.32.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 79)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 80)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 81)) (0.1.1)
# Requirement already satisfied: rpds-py==0.18.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 82)) (0.18.1)
# Requirement already satisfied: Send2Trash==1.8.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 83)) (1.8.3)
# Requirement already satisfied: setuptools==70.1.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 84)) (70.1.0)
# Requirement already satisfied: six==1.16.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 85)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 86)) (1.3.1)
# Requirement already satisfied: soupsieve==2.5 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 87)) (2.5)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 88)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 89)) (0.18.1)
# Requirement already satisfied: tinycss2==1.3.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 90)) (1.3.0)
# Requirement already satisfied: tornado==6.4.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 91)) (6.4.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 92)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20240316 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 93)) (2.9.0.20240316)
# Requirement already satisfied: uri-template==1.3.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 94)) (1.3.0)
# Requirement already satisfied: urllib3==2.2.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 95)) (2.2.2)
# Requirement already satisfied: virtualenv==20.26.2 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 96)) (20.26.2)
# Requirement already satisfied: virtualenvwrapper-win==1.2.7 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 97)) (1.2.7)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 98)) (0.2.13)
# Requirement already satisfied: webcolors==24.6.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 99)) (24.6.0)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 100)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 101)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.11 in c:\users\cnmendes\onedrive - globo comunicação e participações sa\área de trabalho\meu_projeto_coder\lib\site-packages (from -r requirements.txt (line 102)) (4.0.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.6.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.2
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# distlib                   0.3.8
# executing                 2.0.1
# fastjsonschema            2.20.0
# filelock                  3.15.3
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.5
# httpx                     0.27.0
# idna                      3.7
# ipykernel                 6.29.4
# ipython                   8.25.0
# ipywidgets                8.1.3
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.22.0
# jsonschema-specifications 2023.12.1
# jupyter                   1.0.0
# jupyter_client            8.6.2
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.1
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.2
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.2
# jupyterlab_widgets        3.0.11
# MarkupSafe                2.1.5
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.2.1
# notebook_shim             0.2.4
# overrides                 7.7.0
# packaging                 24.1
# pandocfilters             1.5.1
# parso                     0.8.4
# pip                       24.0
# platformdirs              4.2.2
# prometheus_client         0.20.0
# prompt_toolkit            3.0.47
# psutil                    6.0.0
# pure-eval                 0.2.2
# pycparser                 2.22
# Pygments                  2.18.0
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pywin32                   306
# pywinpty                  2.0.13
# PyYAML                    6.0.1
# pyzmq                     26.0.3
# qtconsole                 5.5.2
# QtPy                      2.4.1
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.18.1
# Send2Trash                1.8.3
# setuptools                70.1.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.5
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.3.0
# tornado                   6.4.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# uri-template              1.3.0
# urllib3                   2.2.2
# virtualenv                20.26.2
# virtualenvwrapper-win     1.2.7
# wcwidth                   0.2.13
# webcolors                 24.6.0
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.11
# Note: you may need to restart the kernel to use updated packages.
